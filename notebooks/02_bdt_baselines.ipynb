# %% [markdown]
# # BDT baselines
#
# Saved-result study notebook for Phases 4/7/8 and Phase 2. Each section calls reusable report functions in `src/`. No training or test analysis runs here.

# %%
from hepml.adapters.evaluation_report import default_report_directory, display_baseline_section
REPORT = default_report_directory()

# %%
from hepml.adapters.evaluation_report import display_baseline_section

# %% [markdown]
# ## Question, inputs and fixed choices

# %%
display_baseline_section(REPORT, 'scope')

# %% [markdown]
# ## Integrity and normalization checks

# %%
display_baseline_section(REPORT, 'checks')

# %% [markdown]
# ## Validation results and reference comparisons

# %%
display_baseline_section(REPORT, 'results')

# %% [markdown]
# ## Operating points, MC support and stability

# %%
display_baseline_section(REPORT, 'thresholds')

# %% [markdown]
# ## Checkpoint interpretation

# %%
display_baseline_section(REPORT, 'checkpoint')
