# %% [markdown]
# # Jet-level networks (Phase 10a)
#
# LorentzNet and a Deep Sets control over the three role jets, against the grid's BDTs on the same rows and weights, from saved artifacts. Each section calls reusable report functions in `src/`. No training or test analysis runs here.

# %%
from hepml.adapters.network_report import default_network_report
REPORT = default_network_report()

# %%
from hepml.adapters.network_report import display_network_section

# %% [markdown]
# ## Question, inputs and pre-registered decision

# %%
display_network_section(REPORT, 'scope')

# %% [markdown]
# ## Fits, time and memory

# %%
display_network_section(REPORT, 'inputs')

# %% [markdown]
# ## Contract checks

# %%
display_network_section(REPORT, 'checks')

# %% [markdown]
# ## Primary comparison and descriptive metrics

# %%
display_network_section(REPORT, 'results')

# %% [markdown]
# ## Checkpoint decision

# %%
display_network_section(REPORT, 'checkpoint')
