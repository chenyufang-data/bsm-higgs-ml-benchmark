# %% [markdown]
# # Truth tagging
#
# Closure of truth tagging against direct tagging on simulation, from saved artifacts. Each section calls reusable report functions in `src/`. No training or test analysis runs here.

# %%
from hepml.adapters.truth_tag_report import default_truth_tag_report
REPORT = default_truth_tag_report()

# %%
from hepml.adapters.truth_tag_report import display_truth_tag_section

# %% [markdown]
# ## Question, method and pre-registered gates

# %%
display_truth_tag_section(REPORT, 'scope')

# %% [markdown]
# ## Export consistency and event registry

# %%
display_truth_tag_section(REPORT, 'inputs')

# %% [markdown]
# ## Contract checks and gates

# %%
display_truth_tag_section(REPORT, 'checks')

# %% [markdown]
# ## Tag rates, yields and shapes

# %%
display_truth_tag_section(REPORT, 'results')

# %% [markdown]
# ## Checkpoint decision

# %%
display_truth_tag_section(REPORT, 'checkpoint')
