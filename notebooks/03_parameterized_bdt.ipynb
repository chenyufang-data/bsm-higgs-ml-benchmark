# %% [markdown]
# # Parameterized BDT
#
# Phase 3 (conditioning, loss weights, leakage checks, validation results) and Phase 5 (paired comparison with the mass-specific references) from saved artifacts. The sections adapt to the selected report. Phase 6 interpolation will extend this notebook after its gate.

# %%
from hepml.adapters.parameterized_report import default_parameterized_report
REPORT = default_parameterized_report()

# %%
from hepml.adapters.parameterized_report import display_parameterized_section

# %% [markdown]
# ## Question, inputs and scope

# %%
display_parameterized_section(REPORT, 'scope')

# %% [markdown]
# ## Fitting weights

# %%
display_parameterized_section(REPORT, 'weights')

# %% [markdown]
# ## Integrity, leakage, reload and resource checks

# %%
display_parameterized_section(REPORT, 'checks')

# %% [markdown]
# ## Per-mass validation results

# %%
display_parameterized_section(REPORT, 'results')

# %% [markdown]
# ## Operating points and MC support

# %%
display_parameterized_section(REPORT, 'thresholds')

# %% [markdown]
# ## Checkpoint decision

# %%
display_parameterized_section(REPORT, 'checkpoint')
