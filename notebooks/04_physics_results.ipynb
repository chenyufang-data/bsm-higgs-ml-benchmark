# %% [markdown]
# # Physics results
#
# Expected sensitivity over the mass grid from saved artifacts. Each section calls reusable report functions in `src/`. No training or test analysis runs here.

# %%
from hepml.adapters.grid_report import default_grid_report
REPORT = default_grid_report()

# %%
from hepml.adapters.grid_report import display_grid_section

# %% [markdown]
# ## Question, inputs and scope

# %%
display_grid_section(REPORT, 'scope')

# %% [markdown]
# ## Rates, MC support and registry

# %%
display_grid_section(REPORT, 'inputs')

# %% [markdown]
# ## Integrity and normalization checks

# %%
display_grid_section(REPORT, 'checks')

# %% [markdown]
# ## Sensitivity over the grid

# %%
display_grid_section(REPORT, 'results')

# %% [markdown]
# ## Operating points and MC support

# %%
display_grid_section(REPORT, 'thresholds')

# %% [markdown]
# ## Checkpoint decision

# %%
display_grid_section(REPORT, 'checkpoint')
